# %% [markdown]
# # Selecting Subset of Data

# %%
import pandas as pd

titanic = pd.read_csv('kapal_titanic.csv', index_col = 'sex')
titanic.head()
# Out:
#         survived  pclass   age  sibsp  parch     fare embarked deck
# sex
# male           0       3  22.0      1      0   7.2500        S  NaN
# female         1       1  38.0      1      0  71.2833        C    C
# female         1       3  26.0      0      0   7.9250        S  NaN
# female         1       1  35.0      1      0  53.1000        S    C
# male           0       3  35.0      0      0   8.0500        S  NaN

# %%
titanic['age']
# Out:
# sex
# male      22.0
# female    38.0
# female    26.0
# female    35.0
# male      35.0
#           ...
# male      27.0
# female    19.0
# female     NaN
# male      26.0
# male      32.0
# Name: age, Length: 891, dtype: float64

# %%
titanic.head()
# Out:
#         survived  pclass   age  sibsp  parch     fare embarked deck
# sex
# male           0       3  22.0      1      0   7.2500        S  NaN
# female         1       1  38.0      1      0  71.2833        C    C
# female         1       3  26.0      0      0   7.9250        S  NaN
# female         1       1  35.0      1      0  53.1000        S    C
# male           0       3  35.0      0      0   8.0500        S  NaN

# %%
titanic[['age','fare']]
# Out:
#          age     fare
# sex
# male    22.0   7.2500
# female  38.0  71.2833
# female  26.0   7.9250
# female  35.0  53.1000
# male    35.0   8.0500
# ...      ...      ...
# male    27.0  13.0000
# female  19.0  30.0000
# female   NaN  23.4500
# male    26.0  30.0000
# male    32.0   7.7500
#
# [891 rows x 2 columns]

# %%
cols = ['age', 'fare', 'pclass']
titanic[cols]
# Out:
#          age     fare  pclass
# sex
# male    22.0   7.2500       3
# female  38.0  71.2833       1
# female  26.0   7.9250       3
# female  35.0  53.1000       1
# male    35.0   8.0500       3
# ...      ...      ...     ...
# male    27.0  13.0000       2
# female  19.0  30.0000       1
# female   NaN  23.4500       3
# male    26.0  30.0000       1
# male    32.0   7.7500       3
#
# [891 rows x 3 columns]

# %%
movie = pd.read_csv('movie_metadata.csv', index_col = 'actor_2_name')
movie.head()
# Out:
#                   color      director_name  num_critic_for_reviews  duration  \
# actor_2_name
# Joel David Moore  Color      James Cameron                   723.0     178.0
# Orlando Bloom     Color     Gore Verbinski                   302.0     169.0
# Rory Kinnear      Color         Sam Mendes                   602.0     148.0
# Christian Bale    Color  Christopher Nolan                   813.0     164.0
# Rob Walker          NaN        Doug Walker                     NaN       NaN
#
#                   director_facebook_likes  actor_3_facebook_likes  \
# actor_2_name
# Joel David Moore                      0.0                   855.0
# Orlando Bloom                       563.0                  1000.0
# Rory Kinnear                          0.0                   161.0
# Christian Bale                    22000.0                 23000.0
# Rob Walker                          131.0                     NaN
#
#                   actor_1_facebook_likes        gross  \
# actor_2_name
# ...

# %%
movie['director_name'].head()
# Out:
# actor_2_name
# Joel David Moore        James Cameron
# Orlando Bloom          Gore Verbinski
# Rory Kinnear               Sam Mendes
# Christian Bale      Christopher Nolan
# Rob Walker                Doug Walker
# Name: director_name, dtype: object

# %%
movie[['director_name', 'actor_1_facebook_likes']].head()
# Out:
#                       director_name  actor_1_facebook_likes
# actor_2_name
# Joel David Moore      James Cameron                  1000.0
# Orlando Bloom        Gore Verbinski                 40000.0
# Rory Kinnear             Sam Mendes                 11000.0
# Christian Bale    Christopher Nolan                 27000.0
# Rob Walker              Doug Walker                   131.0

# %%
movie[['duration']].head()
# Out:
#                   duration
# actor_2_name
# Joel David Moore     178.0
# Orlando Bloom        169.0
# Rory Kinnear         148.0
# Christian Bale       164.0
# Rob Walker             NaN

# %%
import pandas as pd

gm = pd.read_excel('Top IMDB Movies.xlsx', index_col = 'Title')
gm.head()
# Out:
#                           Unnamed: 0  Number  \
# Title
# Avengers: Endgame                  0     1.0
# Gisaengchung                       1     2.0
# The Shining                        2     3.0
# The Dark Knight                    3     4.0
# The Shawshank Redemption           4     5.0
#
#                                                      Movie link  Rating  \
# Title
# Avengers: Endgame         https://www.imdb.com/title/tt4154796/     8.6
# Gisaengchung              https://www.imdb.com/title/tt6751668/     8.5
# The Shining               https://www.imdb.com/title/tt0081505/     8.4
# The Dark Knight           https://www.imdb.com/title/tt0468569/     9.0
# The Shawshank Redemption  https://www.imdb.com/title/tt0111161/     9.3
#
#                           Runtime                                    Genre  \
# Title
# Avengers: Endgame         181 min  \nAction, Adventure, Sci-Fi
# Gisaengchung              132 min    \nComedy, Drama, Thriller
# ...

# %%
rows = ['Avengers: Endgame', 'The Dark Knight', 'The Shining']
cols = ['Rating', 'Runtime', 'Genre']

gm.loc[rows, cols]
# Out:
#                    Rating  Runtime                                    Genre
# Title
# Avengers: Endgame     8.6  181 min  \nAction, Adventure, Sci-Fi
# The Dark Knight       9.0  152 min       \nAction, Crime, Drama
# The Shining           8.4  146 min              \nDrama, Horror

# %%
gm.head(10)
# Out:
#                                    Unnamed: 0  Number  \
# Title
# Avengers: Endgame                           0     1.0
# Gisaengchung                                1     2.0
# The Shining                                 2     3.0
# The Dark Knight                             3     4.0
# The Shawshank Redemption                    4     5.0
# Spider-Man: Into the Spider-Verse           5     6.0
# Inglourious Basterds                        6     7.0
# Pulp Fiction                                7     8.0
# Avengers: Infinity War                      8     9.0
# Toy Story 4                                 9    10.0
#
#                                                               Movie link  \
# Title
# Avengers: Endgame                  https://www.imdb.com/title/tt4154796/
# Gisaengchung                       https://www.imdb.com/title/tt6751668/
# The Shining                        https://www.imdb.com/title/tt0081505/
# ...

# %%
gm.loc['Avengers: Endgame':'Pulp Fiction', :]
# Out:
#                                    Unnamed: 0  Number  \
# Title
# Avengers: Endgame                           0     1.0
# Gisaengchung                                1     2.0
# The Shining                                 2     3.0
# The Dark Knight                             3     4.0
# The Shawshank Redemption                    4     5.0
# Spider-Man: Into the Spider-Verse           5     6.0
# Inglourious Basterds                        6     7.0
# Pulp Fiction                                7     8.0
#
#                                                               Movie link  \
# Title
# Avengers: Endgame                  https://www.imdb.com/title/tt4154796/
# Gisaengchung                       https://www.imdb.com/title/tt6751668/
# The Shining                        https://www.imdb.com/title/tt0081505/
# The Dark Knight                    https://www.imdb.com/title/tt0468569/
# The Shawshank Redemption           https://www.imdb.com/title/tt0111161/
# ...

# %%
gm.loc['Avengers: Endgame':'Pulp Fiction', 'Rating':'Votes']
# Out:
#                                    Rating  Runtime  \
# Title
# Avengers: Endgame                     8.6  181 min
# Gisaengchung                          8.5  132 min
# The Shining                           8.4  146 min
# The Dark Knight                       9.0  152 min
# The Shawshank Redemption              9.3  142 min
# Spider-Man: Into the Spider-Verse     8.4  117 min
# Inglourious Basterds                  8.3  153 min
# Pulp Fiction                          8.9  154 min
#
#                                                                         Genre  \
# Title
# Avengers: Endgame                     \nAction, Adventure, Sci-Fi
# Gisaengchung                            \nComedy, Drama, Thriller
# The Shining                                       \nDrama, Horror
# The Dark Knight                            \nAction, Crime, Drama
# The Shawshank Redemption                                  \nDrama
# Spider-Man: Into the Spider-Verse  \nAnimation, Action, Adventure
# ...

# %%
movie = pd.read_excel('Top IMDB Movies.xlsx', index_col = 'Title')
movie.head(3)
# Out:
#                    Unnamed: 0  Number                             Movie link  \
# Title
# Avengers: Endgame           0     1.0  https://www.imdb.com/title/tt4154796/
# Gisaengchung                1     2.0  https://www.imdb.com/title/tt6751668/
# The Shining                 2     3.0  https://www.imdb.com/title/tt0081505/
#
#                    Rating  Runtime                                    Genre  \
# Title
# Avengers: Endgame     8.6  181 min  \nAction, Adventure, Sci-Fi
# Gisaengchung          8.5  132 min    \nComedy, Drama, Thriller
# The Shining           8.4  146 min              \nDrama, Horror
#
#                      Votes  Metascore     Gross  \
# Title
# Avengers: Endgame  558,276         78  $858.37M
# Gisaengchung        29,523         92  $858.37M
# The Shining        798,352         66   $44.02M
#
#                                                                 Plot
# Title
# Avengers: Endgame  \n    After the devastating events of Avengers...
# ...

# %%
movie.loc['The Shining', :]
# Out:
# Unnamed: 0                                                    2
# Number                                                        3
# Movie link                https://www.imdb.com/title/tt0081505/
# Rating                                                      8.4
# Runtime                                                 146 min
# Genre                               \nDrama, Horror
# Votes                                                   798,352
# Metascore                                                    66
# Gross                                                   $44.02M
# Plot          \n    A family heads to an isolated hotel for ...
# Name: The Shining, dtype: object

# %%
rows = ['Avengers: Endgame', 'The Dark Knight']
movie.loc[rows,:]
# Out:
#                    Unnamed: 0  Number                             Movie link  \
# Title
# Avengers: Endgame           0     1.0  https://www.imdb.com/title/tt4154796/
# The Dark Knight             3     4.0  https://www.imdb.com/title/tt0468569/
#
#                    Rating  Runtime                                    Genre  \
# Title
# Avengers: Endgame     8.6  181 min  \nAction, Adventure, Sci-Fi
# The Dark Knight       9.0  152 min       \nAction, Crime, Drama
#
#                        Votes  Metascore     Gross  \
# Title
# Avengers: Endgame    558,276         78  $858.37M
# The Dark Knight    2,099,976         84  $534.86M
#
#                                                                 Plot
# Title
# Avengers: Endgame  \n    After the devastating events of Avengers...
# The Dark Knight    \n    When the menace known as The Joker emerg...

# %%
cols = ['Rating', 'Metascore']
movie.loc[rows,cols]
# Out:
#                    Rating  Metascore
# Title
# Avengers: Endgame     8.6         78
# The Dark Knight       9.0         84

# %%
movie.dtypes
# Out:
# Unnamed: 0      int64
# Number        float64
# Movie link     object
# Rating        float64
# Runtime        object
# Genre          object
# Votes          object
# Metascore       int64
# Gross          object
# Plot           object
# dtype: object

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Avengers: Endgame to Saving Private Ryan
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  50 non-null     int64
#  1   Number      50 non-null     float64
#  2   Movie link  50 non-null     object
#  3   Rating      50 non-null     float64
#  4   Runtime     50 non-null     object
#  5   Genre       50 non-null     object
#  6   Votes       50 non-null     object
#  7   Metascore   50 non-null     int64
#  8   Gross       50 non-null     object
#  9   Plot        50 non-null     object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 6.8+ KB

# %%
titanic
# Out:
#         survived  pclass   age  sibsp  parch     fare embarked deck
# sex
# male           0       3  22.0      1      0   7.2500        S  NaN
# female         1       1  38.0      1      0  71.2833        C    C
# female         1       3  26.0      0      0   7.9250        S  NaN
# female         1       1  35.0      1      0  53.1000        S    C
# male           0       3  35.0      0      0   8.0500        S  NaN
# ...          ...     ...   ...    ...    ...      ...      ...  ...
# male           0       2  27.0      0      0  13.0000        S  NaN
# female         1       1  19.0      0      0  30.0000        S    B
# female         0       3   NaN      1      2  23.4500        S  NaN
# male           1       1  26.0      0      0  30.0000        C    C
# male           0       3  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 8 columns]

# %%
rows = [0,1]
cols = [2,3]
titanic.iloc[rows, cols]
# Out:
#          age  sibsp
# sex
# male    22.0      1
# female  38.0      1

# %%
movie.head()
# Out:
#                           Unnamed: 0  Number  \
# Title
# Avengers: Endgame                  0     1.0
# Gisaengchung                       1     2.0
# The Shining                        2     3.0
# The Dark Knight                    3     4.0
# The Shawshank Redemption           4     5.0
#
#                                                      Movie link  Rating  \
# Title
# Avengers: Endgame         https://www.imdb.com/title/tt4154796/     8.6
# Gisaengchung              https://www.imdb.com/title/tt6751668/     8.5
# The Shining               https://www.imdb.com/title/tt0081505/     8.4
# The Dark Knight           https://www.imdb.com/title/tt0468569/     9.0
# The Shawshank Redemption  https://www.imdb.com/title/tt0111161/     9.3
#
#                           Runtime                                    Genre  \
# Title
# Avengers: Endgame         181 min  \nAction, Adventure, Sci-Fi
# Gisaengchung              132 min    \nComedy, Drama, Thriller
# ...

# %%
rows = [10,5,1]
movie.iloc[rows,:]
# Out:
#                                    Unnamed: 0  Number  \
# Title
# Interstellar                               10    11.0
# Spider-Man: Into the Spider-Verse           5     6.0
# Gisaengchung                                1     2.0
#
#                                                               Movie link  \
# Title
# Interstellar                       https://www.imdb.com/title/tt0816692/
# Spider-Man: Into the Spider-Verse  https://www.imdb.com/title/tt4633694/
# Gisaengchung                       https://www.imdb.com/title/tt6751668/
#
#                                    Rating  Runtime  \
# Title
# Interstellar                          8.6  169 min
# Spider-Man: Into the Spider-Verse     8.4  117 min
# Gisaengchung                          8.5  132 min
#
#                                                                         Genre  \
# Title
# Interstellar                           \nAdventure, Drama, Sci-Fi
# ...

# %%
cols = [7,5,1]
movie.iloc[:, cols].head()
# Out:
#                           Metascore                                    Genre  \
# Title
# Avengers: Endgame                78  \nAction, Adventure, Sci-Fi
# Gisaengchung                     92    \nComedy, Drama, Thriller
# The Shining                      66              \nDrama, Horror
# The Dark Knight                  84       \nAction, Crime, Drama
# The Shawshank Redemption         80                      \nDrama
#
#                           Number
# Title
# Avengers: Endgame            1.0
# Gisaengchung                 2.0
# The Shining                  3.0
# The Dark Knight              4.0
# The Shawshank Redemption     5.0

# %%
movie.iloc[4:7, 5]
# Out:
# Title
# The Shawshank Redemption                                    \nDrama
# Spider-Man: Into the Spider-Verse    \nAnimation, Action, Adventure
# Inglourious Basterds                        \nAdventure, Drama, War
# Name: Genre, dtype: object
