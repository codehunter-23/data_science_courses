# %% [markdown]
# # Chapter 2 : Data Types and Missing Values

# %%
import pandas as pd

bikes = pd.read_csv('Divvy_Trips.csv')
bikes.head()
# Out:
#     TRIP ID              START TIME               STOP TIME  BIKE ID  \
# 0  25962904  12/31/2019 11:57:17 PM  12/31/2019 11:59:18 PM     5930
# 1  25962903  12/31/2019 11:57:11 PM  01/01/2020 12:05:45 AM     2637
# 2  25962902  12/31/2019 11:57:05 PM  01/01/2020 12:05:46 AM      863
# 3  25962901  12/31/2019 11:56:34 PM  01/01/2020 12:22:08 AM     4877
# 4  25962900  12/31/2019 11:56:13 PM  01/01/2020 12:15:45 AM     2196
#
#    TRIP DURATION  FROM STATION ID       FROM STATION NAME  TO STATION ID  \
# 0            120              256  Broadway & Sheridan Rd            240
# 1            514              623   Michigan Ave & 8th St             52
# 2            520              623   Michigan Ave & 8th St             52
# 3           1533               90         Millennium Park             90
# 4           1172              112  Green St & Randolph St            225
#
#                 TO STATION NAME   USER TYPE  GENDER  BIRTH YEAR  \
# ...

# %%
bikes = pd.read_csv('Divvy_Trips.csv', parse_dates = ['START TIME', 'STOP TIME'])
bikes.dtypes
# Out:
# TRIP ID                       int64
# START TIME           datetime64[ns]
# STOP TIME            datetime64[ns]
# BIKE ID                       int64
# TRIP DURATION                 int64
# FROM STATION ID               int64
# FROM STATION NAME            object
# TO STATION ID                 int64
# TO STATION NAME              object
# USER TYPE                    object
# GENDER                       object
# BIRTH YEAR                  float64
# FROM LATITUDE               float64
# FROM LONGITUDE              float64
# FROM LOCATION                object
# TO LATITUDE                 float64
# TO LONGITUDE                float64
# TO LOCATION                  object
# dtype: object

# %% [markdown]
# # Exercise 2

# %%
bikes = pd.read_csv('Divvy_Trips.csv', parse_dates = ['START TIME', 'STOP TIME'])
bikes.head(2)
# Out:
#     TRIP ID          START TIME           STOP TIME  BIKE ID  TRIP DURATION  \
# 0  25962904 2019-12-31 23:57:17 2019-12-31 23:59:18     5930            120
# 1  25962903 2019-12-31 23:57:11 2020-01-01 00:05:45     2637            514
#
#    FROM STATION ID       FROM STATION NAME  TO STATION ID  \
# 0              256  Broadway & Sheridan Rd            240
# 1              623   Michigan Ave & 8th St             52
#
#                 TO STATION NAME   USER TYPE  GENDER  BIRTH YEAR  \
# 0  Sheridan Rd & Irving Park Rd  Subscriber    Male      1982.0
# 1        Michigan Ave & Lake St  Subscriber  Female      1970.0
#
#    FROM LATITUDE  FROM LONGITUDE                 FROM LOCATION  TO LATITUDE  \
# 0      41.952833      -87.649993  POINT (-87.649993 41.952833)    41.954245
# 1      41.872773      -87.623981  POINT (-87.623981 41.872773)    41.886024
#
#    TO LONGITUDE                   TO LOCATION
# 0    -87.654406  POINT (-87.654406 41.954245)
# ...

# %%
bikes.dtypes
# Out:
# TRIP ID                       int64
# START TIME           datetime64[ns]
# STOP TIME            datetime64[ns]
# BIKE ID                       int64
# TRIP DURATION                 int64
# FROM STATION ID               int64
# FROM STATION NAME            object
# TO STATION ID                 int64
# TO STATION NAME              object
# USER TYPE                    object
# GENDER                       object
# BIRTH YEAR                  float64
# FROM LATITUDE               float64
# FROM LONGITUDE              float64
# FROM LOCATION                object
# TO LATITUDE                 float64
# TO LONGITUDE                float64
# TO LOCATION                  object
# dtype: object

# %%
type(bikes.dtypes)
# Out:
# pandas.core.series.Series

# %%
bikes.shape
# Out:
# (2033, 18)

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2033 entries, 0 to 2032
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TRIP ID            2033 non-null   int64
#  1   START TIME         2033 non-null   datetime64[ns]
#  2   STOP TIME          2033 non-null   datetime64[ns]
#  3   BIKE ID            2033 non-null   int64
#  4   TRIP DURATION      2033 non-null   int64
#  5   FROM STATION ID    2033 non-null   int64
#  6   FROM STATION NAME  2033 non-null   object
#  7   TO STATION ID      2033 non-null   int64
#  8   TO STATION NAME    2033 non-null   object
#  9   USER TYPE          2033 non-null   object
#  10  GENDER             2011 non-null   object
#  11  BIRTH YEAR         2029 non-null   float64
#  12  FROM LATITUDE      2033 non-null   float64
#  13  FROM LONGITUDE     2033 non-null   float64
#  14  FROM LOCATION      2033 non-null   object
# ...

# %%
bk = pd.read_csv('Divvy_Trips.csv', index_col=6)
bk.head()
# Out:
#                          TRIP ID              START TIME  \
# FROM STATION NAME
# Broadway & Sheridan Rd  25962904  12/31/2019 11:57:17 PM
# Michigan Ave & 8th St   25962903  12/31/2019 11:57:11 PM
# Michigan Ave & 8th St   25962902  12/31/2019 11:57:05 PM
# Millennium Park         25962901  12/31/2019 11:56:34 PM
# Green St & Randolph St  25962900  12/31/2019 11:56:13 PM
#
#                                      STOP TIME  BIKE ID  TRIP DURATION  \
# FROM STATION NAME
# Broadway & Sheridan Rd  12/31/2019 11:59:18 PM     5930            120
# Michigan Ave & 8th St   01/01/2020 12:05:45 AM     2637            514
# Michigan Ave & 8th St   01/01/2020 12:05:46 AM      863            520
# Millennium Park         01/01/2020 12:22:08 AM     4877           1533
# Green St & Randolph St  01/01/2020 12:15:45 AM     2196           1172
#
#                         FROM STATION ID  TO STATION ID  \
# FROM STATION NAME
# Broadway & Sheridan Rd              256            240
# ...

# %%
bk.index
# Out:
# Index(['Broadway & Sheridan Rd', 'Michigan Ave & 8th St',
#        'Michigan Ave & 8th St', 'Millennium Park', 'Green St & Randolph St',
#        'Mies van der Rohe Way & Chestnut St', 'Maplewood Ave & Peterson Ave',
#        'Clinton St & Jackson Blvd', 'Indiana Ave & Roosevelt Rd',
#        'Dearborn St & Van Buren St',
#        ...
#        'State St & Kinzie St', 'Sheffield Ave & Fullerton Ave',
#        'Dearborn St & Erie St', 'Lincoln Ave & Diversey Pkwy',
#        'Sheridan Rd & Irving Park Rd', 'Wabash Ave & Grand Ave',
#        'Seeley Ave & Roscoe St', 'Clinton St & Madison St',
#        'Franklin St & Illinois St', 'Ashland Ave & Grace St'],
#       dtype='object', name='FROM STATION NAME', length=2033)

# %%
bk.columns
# Out:
# Index(['TRIP ID', 'START TIME', 'STOP TIME', 'BIKE ID', 'TRIP DURATION',
#        'FROM STATION ID', 'TO STATION ID', 'TO STATION NAME', 'USER TYPE',
#        'GENDER', 'BIRTH YEAR', 'FROM LATITUDE', 'FROM LONGITUDE',
#        'FROM LOCATION', 'TO LATITUDE', 'TO LONGITUDE', 'TO LOCATION'],
#       dtype='object')

# %%
bk.values
# Out:
# array([[25962904, '12/31/2019 11:57:17 PM', '12/31/2019 11:59:18 PM',
#         ..., 41.954245, -87.65440600000001,
#         'POINT (-87.654406 41.954245)'],
#        [25962903, '12/31/2019 11:57:11 PM', '01/01/2020 12:05:45 AM',
#         ..., 41.886024, -87.624117, 'POINT (-87.624117 41.886024)'],
#        [25962902, '12/31/2019 11:57:05 PM', '01/01/2020 12:05:46 AM',
#         ..., 41.886024, -87.624117, 'POINT (-87.624117 41.886024)'],
#        ...,
#        [25960619, '12/31/2019 12:07:23 AM', '12/31/2019 12:12:54 AM',
#         ..., 41.891578, -87.648384, 'POINT (-87.648384 41.891578)'],
#        [25960618, '12/31/2019 12:04:36 AM', '12/31/2019 12:07:57 AM',
#         ..., 41.893992, -87.62931800000001,
#         'POINT (-87.629318 41.893992)'],
#        [25960617, '12/31/2019 12:02:30 AM', '12/31/2019 12:09:15 AM',
#         ..., 41.95602, -87.680293, 'POINT (-87.680293 41.95602)']],
#       dtype=object)

# %%
import pandas as pd

movie = pd.read_csv('movie_metadata.csv', index_col = 'director_name')
movie.head()
# Out:
#                    color  num_critic_for_reviews  duration  \
# director_name
# James Cameron      Color                   723.0     178.0
# Gore Verbinski     Color                   302.0     169.0
# Sam Mendes         Color                   602.0     148.0
# Christopher Nolan  Color                   813.0     164.0
# Doug Walker          NaN                     NaN       NaN
#
#                    director_facebook_likes  actor_3_facebook_likes  \
# director_name
# James Cameron                          0.0                   855.0
# Gore Verbinski                       563.0                  1000.0
# Sam Mendes                             0.0                   161.0
# Christopher Nolan                  22000.0                 23000.0
# Doug Walker                          131.0                     NaN
#
#                        actor_2_name  actor_1_facebook_likes        gross  \
# director_name
# James Cameron      Joel David Moore                  1000.0  760505847.0
# ...

# %%
idx = movie.index
idx
# Out:
# Index([    'James Cameron',    'Gore Verbinski',        'Sam Mendes',
#        'Christopher Nolan',       'Doug Walker',    'Andrew Stanton',
#                'Sam Raimi',      'Nathan Greno',       'Joss Whedon',
#              'David Yates',
#        ...
#            'Shane Carruth',  'Neill Dela Llana',  'Robert Rodriguez',
#          'Anthony Vallone',      'Edward Burns',       'Scott Smith',
#                        nan,  'Benjamin Roberds',       'Daniel Hsia',
#                 'Jon Gunn'],
#       dtype='object', name='director_name', length=5043)

# %%
type(idx)
# Out:
# pandas.core.indexes.base.Index

# %%
idx[5]
# Out:
# 'Andrew Stanton'

# %% [markdown]
# # Exercise

# %%
pd.set_option('display.max_columns', 20)
movie = pd.read_csv('movie_metadata.csv')
movie.head(3)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
# 2  Color      Sam Mendes                   602.0     148.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# ...

# %%
movie = pd.read_csv('movie_metadata.csv', index_col = 'actor_2_name')
movie.head()
# Out:
#                   color      director_name  num_critic_for_reviews  duration  \
# actor_2_name
# Joel David Moore  Color      James Cameron                   723.0     178.0
# Orlando Bloom     Color     Gore Verbinski                   302.0     169.0
# Rory Kinnear      Color         Sam Mendes                   602.0     148.0
# Christian Bale    Color  Christopher Nolan                   813.0     164.0
# Rob Walker          NaN        Doug Walker                     NaN       NaN
#
#                   director_facebook_likes  actor_3_facebook_likes  \
# actor_2_name
# Joel David Moore                      0.0                   855.0
# Orlando Bloom                       563.0                  1000.0
# Rory Kinnear                          0.0                   161.0
# Christian Bale                    22000.0                 23000.0
# Rob Walker                          131.0                     NaN
#
#                   actor_1_facebook_likes        gross  \
# actor_2_name
# ...

# %%
movie2 = pd.read_csv('movie_metadata.csv')
movie2.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movie2.set_index('director_name')
# Out:
#                    color  num_critic_for_reviews  duration  \
# director_name
# James Cameron      Color                   723.0     178.0
# Gore Verbinski     Color                   302.0     169.0
# Sam Mendes         Color                   602.0     148.0
# Christopher Nolan  Color                   813.0     164.0
# Doug Walker          NaN                     NaN       NaN
# ...                  ...                     ...       ...
# Scott Smith        Color                     1.0      87.0
# NaN                Color                    43.0      43.0
# Benjamin Roberds   Color                    13.0      76.0
# Daniel Hsia        Color                    14.0     100.0
# Jon Gunn           Color                    43.0      90.0
#
#                    director_facebook_likes  actor_3_facebook_likes  \
# director_name
# James Cameron                          0.0                   855.0
# Gore Verbinski                       563.0                  1000.0
# ...

# %%
m3 = movie2.set_index('director_name', drop=False)
m3.head()
# Out:
#                    color      director_name  num_critic_for_reviews  duration  \
# director_name
# James Cameron      Color      James Cameron                   723.0     178.0
# Gore Verbinski     Color     Gore Verbinski                   302.0     169.0
# Sam Mendes         Color         Sam Mendes                   602.0     148.0
# Christopher Nolan  Color  Christopher Nolan                   813.0     164.0
# Doug Walker          NaN        Doug Walker                     NaN       NaN
#
#                    director_facebook_likes  actor_3_facebook_likes  \
# director_name
# James Cameron                          0.0                   855.0
# Gore Verbinski                       563.0                  1000.0
# Sam Mendes                             0.0                   161.0
# Christopher Nolan                  22000.0                 23000.0
# Doug Walker                          131.0                     NaN
#
# ...

# %%
idx = m3.index
idx[-10:]
# Out:
# Index([   'Shane Carruth', 'Neill Dela Llana', 'Robert Rodriguez',
#         'Anthony Vallone',     'Edward Burns',      'Scott Smith',
#                       nan, 'Benjamin Roberds',      'Daniel Hsia',
#                'Jon Gunn'],
#       dtype='object', name='director_name')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-c59ff0908b0d> in <module>
# ----> 1 idx.tail(10)
#
# AttributeError: 'Index' object has no attribute 'tail'
